# %% [markdown]
# # 🔌 Energy Consumption Analysis
#
# ## 📌 Problem Statement
# Energy consumption in households varies widely, leading to billing disputes and energy wastage.
#
# ## 🎯 Objective
# - Analyze energy usage patterns
# - Detect abnormal consumption (anomalies)
# - Generate insights for better energy management
#
# ## 📂 Dataset
# Individual Household Electric Power Consumption Dataset
#
# ## 🧠 Approach
# We will follow the Data Science lifecycle:
# 1. Data Loading
# 2. Data Cleaning
# 3. Feature Engineering
# 4. Exploratory Data Analysis (EDA)
# 5. Insight Generation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("ggplot")

# %%
df = pd.read_csv("energy.csv", sep=";")
df.head()

# %% [markdown]
# ## 🔍 Data Inspection
#
# We inspect the dataset to understand:
# - Structure
# - Data types
# - Missing values

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# ## 🧹 Data Cleaning
#
# Steps:
# - Replace '?' with null values
# - Remove missing values
# - Remove duplicate records

# %%
df.replace("?", None, inplace=True)
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
